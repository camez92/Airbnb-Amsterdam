# %% [markdown]
# # Airbnb Amsterdam
#
# #### 1. Import Libraries
#
# #### 2. Import Data
#
# #### 3. Creating Subset
#
# #### 4. Investigating relationships between variables
#
# #### 5. Key Questions/Hypothesis

# %% [markdown]
# # 1. Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Check matplotlib version

matplotlib.__version__
# Out:
# '3.7.0'

# %%
# Ensure charts are displayed without having to call them specifically

# %matplotlib inline

# %% [markdown]
# # 2. Importing Data

# %%
#assigning the Path to the folder
path = r'C:\Users\H539822\Desktop\Airbnb_Amsterdam'

# %%
# Import the dataframe

listings_merge = pd.read_csv(os.path.join(path, 'listings_merge.csv'))

# %%
listings_merge.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1   3209                  Quiet apt near center, great view     3806
# 2  20168         100%Centre-Studio 1 Private Floor/Bathroom    59484
# 3  25428                Lovely apt in City Centre (Jordaan)    56142
# 4  27886  Romantic, stylish B&B houseboat in canal district    97647
#
#   host_name                           neighbourhood   latitude  longitude  \
# 0    Daniel  Oostelijk Havengebied - Indische Buurt  52.365755   4.941419
# 1   Maartje                              Westerpark  52.390225   4.873924
# 2      Alex                            Centrum-Oost  52.365087   4.893541
# 3      Joan                            Centrum-West  52.373114   4.883668
# 4      Flip                            Centrum-West  52.386727   4.892078
#
#          room_type  price  minimum_nights  ...  maximum_nights  \
# ...

# %%
listings_merge.shape
# Out:
# (20030, 35)

# %%
listings_merge.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'property_type',
#        'accommodates', 'first_review', 'review_scores_value',
#        'review_scores_cleanliness', 'review_scores_location',
#        'review_scores_accuracy', 'review_scores_communication',
#        'review_scores_checkin', 'review_scores_rating', 'maximum_nights',
#        'listing_url', 'host_is_superhost', 'host_about', 'host_response_time',
#        'host_response_rate', 'street', 'weekly_price', 'monthly_price',
#        'market'],
#       dtype='object')

# %% [markdown]
# # 3. Creating Subset

# %%
# Create a correlation matrix using pandas
listings_merge.corr()
# Out:
# C:\Users\H539822\AppData\Local\Temp\ipykernel_61532\1809273328.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   listings_merge.corr()
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.506675 -0.016363   0.002785
# host_id                         0.506675  1.000000 -0.014046   0.029208
# latitude                       -0.016363 -0.014046  1.000000  -0.137699
# longitude                       0.002785  0.029208 -0.137699   1.000000
# price                           0.021963  0.014464  0.006163   0.017813
# minimum_nights                 -0.028927 -0.019406 -0.007749   0.001013
# number_of_reviews              -0.341917 -0.147320  0.038902   0.005360
# reviews_per_month               0.105814  0.115603  0.028684   0.003834
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(listings_merge.corr())
plt.show()
# Out:
# C:\Users\H539822\AppData\Local\Temp\ipykernel_61532\3939603473.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(listings_merge.corr())

# %%
# Save figure
plt.matshow(listings_merge.corr())
plt.savefig("out.png")
# Out:
# C:\Users\H539822\AppData\Local\Temp\ipykernel_61532\2631437010.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(listings_merge.corr())

# %%
f = plt.figure(figsize=(15, 15)) # figure size 
plt.matshow(listings_merge.corr(), fignum=f.number) # type of plot
plt.xticks(range(listings_merge.shape[1]), listings_merge.columns, fontsize=12, rotation=45) # x axis labels
plt.yticks(range(listings_merge.shape[1]), listings_merge.columns, fontsize=12) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=12) # add font size
plt.title('Correlation Matrix', fontsize=12) # add title
# Out:
# C:\Users\H539822\AppData\Local\Temp\ipykernel_61532\3491352703.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(listings_merge.corr(), fignum=f.number) # type of plot
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# #### We are going to do some analysis regarding only numerical values. For this reason I'm going to create a dataframe containing only the variables needed for this purpose. To many values we have right now

# %%
# Create a subset
sub = listings_merge[['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365']]

# %%
sub.head()
# Out:
#     latitude  longitude  price  minimum_nights  number_of_reviews  \
# 0  52.365755   4.941419     59               3                248
# 1  52.390225   4.873924    160               4                 42
# 2  52.365087   4.893541     80               1                233
# 3  52.373114   4.883668    125              14                  1
# 4  52.386727   4.892078    150               2                171
#
#    calculated_host_listings_count  availability_365
# 0                               1                44
# 1                               1                47
# 2                               2               198
# 3                               2               141
# 4                               1               199

# %%
sub.shape
# Out:
# (20030, 7)

# %%
sub
# Out:
#         latitude  longitude  price  minimum_nights  number_of_reviews  \
# 0      52.365755   4.941419     59               3                248
# 1      52.390225   4.873924    160               4                 42
# 2      52.365087   4.893541     80               1                233
# 3      52.373114   4.883668    125              14                  1
# 4      52.386727   4.892078    150               2                171
# ...          ...        ...    ...             ...                ...
# 20025  52.345999   4.952145    340               7                  0
# 20026  52.362412   4.932467    150               3                  0
# 20027  52.362431   4.926912     80              10                  0
# 20028  52.363780   4.932493     55               2                  0
# 20029  52.346911   4.901932    220               5                  0
#
#        calculated_host_listings_count  availability_365
# 0                                   1                44
# ...

# %% [markdown]
# # 4. Investigating relationships between variables

# %% [markdown]
# ## Correlations

# %%
sub.corr(numeric_only=True)
# Out:
#                                 latitude  longitude     price  minimum_nights  \
# latitude                        1.000000  -0.137699  0.006163       -0.007749
# longitude                      -0.137699   1.000000  0.017813        0.001013
# price                           0.006163   0.017813  1.000000        0.039119
# minimum_nights                 -0.007749   0.001013  0.039119        1.000000
# number_of_reviews               0.038902   0.005360 -0.067417       -0.022019
# calculated_host_listings_count  0.006583  -0.012077  0.017409       -0.007225
# availability_365                0.011300   0.016150  0.159293        0.059486
#
#                                 number_of_reviews  \
# latitude                                 0.038902
# longitude                                0.005360
# price                                   -0.067417
# minimum_nights                          -0.022019
# number_of_reviews                        1.000000
# ...

# %%
corr_figure = plt.figure(figsize=(10, 10)) # Size of the figure
plt.matshow(sub.corr(numeric_only=True), fignum=corr_figure.number) # Type of plot, correlation heatmap
plt.xticks(range(sub.shape[1]), sub.columns, fontsize=14, rotation=90) # x axis labels
plt.yticks(range(sub.shape[1]), sub.columns, fontsize=14) # y axis labels
corr_cb = plt.colorbar() # add a colorbar
corr_cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(numeric_only=True), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# There are weak positive correlations between availabilty_365 and price, availabilty_365 and number_of_reviews.

# %% [markdown]
# ## Scatterplots

# %%
# Create a scatterplot for the "availability_365" and "number_of_reviews" columns in seaborn

sns.lmplot(x = 'number_of_reviews', y = 'availability_365', data = listings_merge)

# %%
# Create a scatterplot for the "availability_365" and "price" columns in seaborn

sns.lmplot(x = 'price', y = 'availability_365', data = listings_merge)

# %% [markdown]
# This doesn show much of a trend but most of the prices 0 - 1500 euro, many outliers are present. Same goes for number of reviews 0 - 300 reviews to seem most of the reviews end and the rest can be argues as outliers.

# %% [markdown]
# ## Pair Plots

# %%
# Keep only the variables you want to use in the pair plot

sub2 = listings_merge[['price', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365']]

# %%
# Create a pair plot 

g = sns.pairplot(sub2)

# %% [markdown]
# Seems like a lot of Categorical data can be plotted from this.

# %% [markdown]
# ## Categorical Plot

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, you can determine sensible categories for the ranges. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution
sns.histplot(sub2['price'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# Create the first category

listings_merge.loc[listings_merge['price'] <= 50, 'Price Category'] = 'Low Price'

# %%
listings_merge.loc[(listings_merge['price'] > 50) & (listings_merge['price'] <= 100), 'Price Category'] = 'Middle Price'

# %%
listings_merge.loc[listings_merge['price'] > 100, 'Price Category'] = 'High Price'

# %%
listings_merge['Price Category'].value_counts(dropna = False)
# Out:
# High Price      13308
# Middle Price     6152
# Low Price         570
# Name: Price Category, dtype: int64

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="number_of_reviews", y="price", hue="Price category", data=listings_merge)

# %% [markdown]
# If there are less reviews left by customers, the more likely it will be middle priced and not high priced.

# %% [markdown]
# # 5. Key Questions/Hypothesis

# %% [markdown]
# What are the prices when more or less reviews are left by customers?
#         The only real answer that can be said is that if there none to very few reviews left by customers the price can still           be middle priced but not very likely.

# %% [markdown]
# Key Questions to look into the future?
#
# Which neighborhoods more expensive?
#
# How do the seasons play a role in pricing?
